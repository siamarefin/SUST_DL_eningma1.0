# %%
# !nvidia-smi
# Out:
# Tue Jan 23 09:49:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P0              28W /  70W |    267MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.8/702.8 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 59.3MB/s]

# %%
 import ultralytics
 ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)

# %% [markdown]
# # custom train

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks
# Out:
# /content/drive/MyDrive/Colab_Notebooks

# %%
# !ls
# Out:
# advance_home_price.ipynb  DL.ipynb		 loss_function.ipynb  yolov8_custom_train.ipynb
# data			  GD2.ipynb		 runs		      yolov8m.pt
# data.yaml		  gradient_decent.ipynb  yolo_train.ipynb     yolov8n.pt

# %% [markdown]
# # train model

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks
# !yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=143 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/Colab_Notebooks
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # validate model

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/Colab_Notebooks/runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 15.9MB/s]
# val: Scanning /content/drive/MyDrive/Colab_Notebooks/data/valid/labels.cache... 31 images, 0 backgrounds, 0 corrupt: 100% 31/31 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.90s/it]
#                    all         31        101      0.832      0.854      0.884      0.515
#                 Helmet         31         18      0.848          1      0.995      0.669
#                Goggles         31          9      0.578      0.889      0.854      0.378
#                 Jacket         31         14      0.926      0.889      0.928      0.643
#                 Gloves         31         52       0.81        0.5      0.649       0.32
# ...

# %% [markdown]
# # epoch  25 na diya 143 dile 1 % moto bare

# %% [markdown]
# # INFERENCE

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Colab_Notebooks/runs/detect/train/weights/best.pt conf=0.25 source =/content/chittagong_bohoddarhat1_10030.jpg
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/chittagong_bohoddarhat1_10030.jpg: 128x224 (no detections), 204.9ms
# Speed: 1.3ms preprocess, 204.9ms inference, 64.9ms postprocess per image at shape (1, 3, 128, 224)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # single image predict

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Colab_Notebooks/runs/detect/train/weights/best.pt conf=0.25 source =/content/siam.png
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/siam.png: 224x192 1 Helmet, 1 Goggles, 1 Jacket, 1 Gloves, 78.1ms
# Speed: 1.5ms preprocess, 78.1ms inference, 658.0ms postprocess per image at shape (1, 3, 224, 192)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
