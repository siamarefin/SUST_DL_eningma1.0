# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.8/702.8 kB 6.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks
# Out:
# /content/drive/MyDrive/Colab_Notebooks

# %%
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/chittagong_bohoddarhat1_10030.jpg: 128x224 (no detections), 80.4ms
# Speed: 10.4ms preprocess, 80.4ms inference, 106.6ms postprocess per image at shape (1, 3, 128, 224)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
